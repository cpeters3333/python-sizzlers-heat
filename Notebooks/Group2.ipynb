# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### More Chicagoans lacked heat in January than any month since 2019 amid historic cold
#
# 1. Go to the Chicago Data Portal: https://data.cityofchicago.org/
# 2. Find each dataset. Building violations, ward, and police.
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %%
build = pd.read_csv('https://data.cityofchicago.org/resource/22u3-xenr.csv?$limit=3000000')

# %%
# you can use any of these
ward = gpd.read_file('https://data.cityofchicago.org/api/geospatial/sp34-6z76?method=export&format=GeoJSON')
police = gpd.read_file('https://data.cityofchicago.org/api/geospatial/fthy-xz3r?method=export&format=GeoJSON')

# %%
build.head()
# Out:
#         id violation_last_modified_date           violation_date  \
# 0  7145390      2024-04-08T08:40:53.000  2024-04-08T00:00:00.000
# 1  7145597      2024-04-08T15:01:15.000  2024-04-08T00:00:00.000
# 2  7145566      2024-04-08T13:05:51.000  2024-04-08T00:00:00.000
# 3  7145562      2024-04-08T13:05:51.000  2024-04-08T00:00:00.000
# 4  7145391      2024-04-08T08:40:53.000  2024-04-08T00:00:00.000
#
#   violation_code violation_status violation_status_date  \
# 0       CN111025             OPEN                   NaN
# 1         BR1001             OPEN                   NaN
# 2       CN061014             OPEN                   NaN
# 3       CN106015             OPEN                   NaN
# 4       CN111085             OPEN                   NaN
#
#             violation_description   violation_location  \
# 0                EGRESS -BASEMENT  OTHER   :    :OTHER
# 1    OWNER OR LICENSED CONTRACTOR                  NaN
# 2            REPAIR EXTERIOR WALL       EXTERIOR:E   :
# 3    REPAIR INTERIOR STAIR SYSTEM       INTERIOR:002 :
# 4  CEILING HEIGHT - 7' - BASEMENT  OTHER   :    :OTHER
#
#                         violation_inspector_comments  \
# 0              BASEMENT APARTMENT HAS ONE EXIT ONLY.
# 1                                                NaN
# 2  EAST AND NORTH ELEVATION  - SPALLED AND ERODED...
# 3  FRONT STAIRWAY - LOOSE TREADS AT VARIOUS LOCAT...
# 4                  BASEMENT CEILING HEIGHT IS 6'-7".
#
#                                  violation_ordinance  ...            address  \
# 0  Provide sufficient means of egress. (13-196-05...  ...  4752 S KEELER AVE
# 1  The code violations listed below must be corre...  ...   120 W MADISON ST
# 2  Failed to maintain the exterior walls of a bui...  ...   1050 N DAMEN AVE
# 3  Failed to maintain interior stairway system in...  ...   1050 N DAMEN AVE
# 4  Increase ceiling height to 7 ft. (13-48-010 th...  ...  4752 S KEELER AVE
#
#    street_number street_direction street_name street_type property_group ssa  \
# 0           4752                S      KEELER         AVE         325206 NaN
# 1            120                W     MADISON          ST           1025 NaN
# 2           1050                N       DAMEN         AVE           3463 NaN
# 3           1050                N       DAMEN         AVE           3463 NaN
# 4           4752                S      KEELER         AVE         325206 NaN
#
#     latitude  longitude                                         location
# 0  41.806239 -87.728582  \n,  \n(41.806239439020445, -87.72858189193624)
# 1  41.882081 -87.631513   \n,  \n(41.882081136557176, -87.6315134139163)
# 2  41.901074 -87.677346    \n,  \n(41.90107387387168, -87.6773459122158)
# 3  41.901074 -87.677346    \n,  \n(41.90107387387168, -87.6773459122158)
# 4  41.806239 -87.728582  \n,  \n(41.806239439020445, -87.72858189193624)
#
# [5 rows x 26 columns]

# %%
build.shape
# Out:
# (1905667, 26)
